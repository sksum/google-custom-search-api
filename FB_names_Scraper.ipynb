# %%
# Importing libraries :
import requests as rq
from bs4 import BeautifulSoup
import re
import time
import sys
import pandas as pd
import maskpass
from datetime import datetime
import json

# %%
# FacebookPost class

class FacebookPost():
    
    POST_LOGIN_URL="https://m.facebook.com/login.php?refsrc=https%3A%2F%2Fm.facebook.com%2F&refid=8"
   
    
    def login():
        """
        Login to Facebook
        
        """
        ###### ENTER PASSWORD AND EMAIL ID####################
        email=str(" ")
        password=" "
        login={
            'email':email,
            'pass':password
            }
        print("Logged In")
        return login
    
    payload=login() 
    
        
    def parse_html(self,request_url,session):
     
        post=session.post(self.POST_LOGIN_URL,data=self.payload) 
        page =session.get(request_url)
        return page


    def Soup(self,page):
        """
        Returns
        -------
        soup : Beautiful Soup object 
        """
  
        soup=BeautifulSoup(page.content,"html.parser")
        return soup
    
    
    def get_page(self,request_url,session):

        page=session.get(request_url) 
        soup=self.Soup(page)
        return soup
    
    
    
    def url_Keyword(self,key):
        """
        search for the post key using mbasic.facebook.com
        
        """
        url=key.replace('www','mbasic')
        #url=key.replace("%20","+")
        
        return url
    
    
    
    def clean_url(self,Urls_list,URLS):
        """
        Clean post URL
        
        """
        for i in range(len(Urls_list)):
            
            #www.facebook.com
            f_url=Urls_list[i].replace('https://m.facebook.com','')
            f_url=f_url.replace("&__tn__=%2As",'')
            f_url=f_url.replace("&__tn__=%2AW",'')
            f_url=f_url.replace("&__tn__=EH",'')
            f_url=f_url.replace("?__tn__=%2AW",'')            
            f_url=f_url.replace("?#footer_action_list",'')
            f_url=f_url.replace("#footer_action_list",'')
            URLS.append('https://www.facebook.com'+ f_url)
            
            #mbasic urls:
            Urls_list[i]=Urls_list[i].replace('https://m.facebook.com','')
            Urls_list[i]='https://mbasic.facebook.com'+ Urls_list[i]
        
        return Urls_list,URLS
    
   
    
    def get_images(self,soup,Images):
        """
        Extract and Clean Images URLs

        """
        
        img=soup.find_all('a',href=re.compile("/photo.php?fbid="))
        img1=soup.find_all('a',href=re.compile("/photo"))
        m=' '
        if img !=[]:
            img_href='https://www.facebook.com'+img[0]['href']
            m+=img_href+'\n'
            
        elif img1 !=[]:
            img_href='https://www.facebook.com'+img1[0]['href']
            m+=img_href+'\n'
            
        else:
            img=soup.find_all('a',href=re.compile("pcb"))
            if img !=[]:
                for i in img:
                    img_href='https://www.facebook.com'+i['href']
                    m+=img_href+'\n'    
    
            
            else:
                img=soup.find_all('a',href=re.compile("photos"))
                if img !=[]:
                    for i in img:
                        img_href='https://www.facebook.com'+i['href']
                        m+=img_href+'\n'
                                                 
        Images.append(m)
        
        return Images
      
    
    
    def posts_info(self,soup,Urls_list,Likes,URLS,Date):
        """
        This function returns the posts urls list  and also the posts descriptions
        
        """
        
        while 1:
            time.sleep(0.2)
            post=soup.find_all('div',class_="by")        
            for i in post:
                l=i.find('span',id=re.compile("like_"))
                Hr=i.find('a',href=re.compile("#footer_action_list"))
                if Hr==None:
                    Hr=i.find('a',href=re.compile("/story.php"))
                   
                        
                d=i.find('abbr')
                
                if Hr!=None:
                    Href=Hr['href']
                    Href=Href.replace('https://m.facebook.com','')
                    Href=Href.replace('https://mbasic.facebook.com','')                    
                    Urls_list.append(Href)
                    if d !=None:
                        date=d.get_text()
                        Date.append(date)
                    else:
                        Date.append('None')
   
                    if l!=None:    
                        if l.get_text()!=None:
                            likes=l.get_text()
                            if likes=="Like · React":
                                likes='0'
                            else:
                                likes=likes.replace('· Like · React','')                                
                                likes=likes.replace("· Like",'')
                                likes=likes.replace("· Love",'')
                                likes=likes.replace("· Haha",'')
                                likes=likes.replace("· Care",'')
                                likes=likes.replace("· Wow",'')
                                likes=likes.replace("· Angry",'')
                            Likes.append(likes)
                        else:
                           Likes.append("0")
                    else:
                        Likes.append("0")
           
                        
            more=self.more_page(soup)
            if more !=None:
                soup=self.get_page(more,session)
                
            else:
                break
                        
        Urls_list,URLS=self.clean_url(Urls_list,URLS)            
                
        return Urls_list,URLS,Likes,Date

    
    
    def get_profile(self,soup,Name,Profile_url):
        """
        Extract Profiles (Name and URLs)
        """
        h3=soup.find("h3")
        
        if h3 !=None:
            if h3.find("a")!=None:           
                name=h3.a.get_text()
                if h3.a.has_attr('href') :
                    h3_a_tag=h3.a['href']
                    h3_a_tag=h3_a_tag.replace("&__tn__=C-R",'')
                                        
                    profile_url='https://www.facebook.com'+h3_a_tag
                else :
                    profile_url="None"
            
        else :
            h31=soup.find('a',class_="actor-link")
            if h31!=None:
                name=h31.get_text()
                if h31.has_attr('href'):
                    profile_url='https://www.facebook.com'+h31['href']
                else:    
                    profile_url="None"
            else:
 
                name="None"
                profile_url="None"
       
            
        Name.append(name)
        Profile_url.append(profile_url)
        
        return Name,Profile_url
    
    
    
    def get_description(self,soup,descreption):
        """
        Extract Post description
        
        """
     
        p=soup.findAll("p")
            
        if p!=[]:
            s=' ' 
            for i in p:
                s+=i.get_text()+' '
            description.append(s)     
        else :
            s=' '
            h11=soup.find('div',{'data-ft':'{"tn":"*s"}'})
            if h11!=None:
                s+=h11.get_text()
                description.append(s)
                
                
            else:
                h12=soup.find('div',{'data-ft':'{"tn":",g"}'})
                if h12!=None:
                    s+=h12.get_text().split(" · in Timeline")[0].replace('· Public','')
                    description.append(s)
                
                else:
                    
                    description.append("None")
                
        return description  
    
    
         
    
    def more_page(self,soup):
        """
        returns : url of the next search page
        
        """
        if soup.find('div',id='see_more_pager')!=None:
            more=soup.find('div',id='see_more_pager').find('a',href=True)['href']
        else:
            more=None
        return more
       
        
    
    
    def get_reactions(self,Post_soup,session):
        """
        get_reactions returns a list of the psot reactions

        """
        React=['Like', 'Angry', 'Love', 'Haha', 'Sad','Care', 'Wow']        
        Nbr_Reactions=['0' for i in range(7)]
        Reactions_url_tag=Post_soup.find('a',href=re.compile('/ufi/reaction/profile/'))
        
        
        if Reactions_url_tag != None:
            
            Reactions_url="https://mbasic.facebook.com/"+Reactions_url_tag['href']
            
            #Beautiful Soup Object:
            Reaction_soup=FP.get_page(Reactions_url,session)
            
            #Extract the class of Reactions:
            React_a=Reaction_soup.findAll('a',class_='u')
            
            for i in React_a:
                React_img=i.find('img')
                if React_img !=None:
                    if React_img.has_attr('alt'):
                        R_alt=React_img['alt']
                                        
                        for j in range(len(React)):
                            if R_alt==React[j]:
                               
                                Nbr_Reactions[j]=i.get_text()
                                
                                                                                            
        return  Nbr_Reactions   
    
        
    
    def more_comments(self,soup):
        """
        Returns
        -------
        more_comments 
        """
        if soup.find('div',id=re.compile("see_next_"))!=None:
            more_comments=soup.find('div',id=re.compile("see_next_")).find('a',href=True)['href'] 
            more_comments=more_comments.replace('https://m.facebook.com','')
        else:
            more_comments=None
        return more_comments
    
            
    def get_comments(self,soup,d_comments,d_profiles,comments_limit):
        
        nbr=0
        while nbr<=comments_limit: #the maximum value of comments we want to scrap
        #Extraction of who comments in this post :
            
            CommentsTag=soup.find_all('h3')
            profile_comments,Name=[],[]
            
            if CommentsTag!=[]:
                for i in CommentsTag:
                    a_tag=i.find('a')
                    if a_tag !=None:
                        if a_tag.has_attr('href'):
                            a_href=a_tag['href']
                            if ("refid=52&__tn__=R" in a_href) or('refid=18&__tn__=R' in a_href)or("?rc=p&__tn__=R" in a_href) :
                                a_href=a_href.replace("&refid=52&__tn__=R",'')
                                a_href=a_href.replace("refid=52&__tn__=R",'')
                                a_href=a_href.replace("&refid=18&__tn__=R",'')
                                a_href=a_href.replace("?refid=18&__tn__=R",'')                                                                
                                a_href_url='https://www.facebook.com'+a_href
                                profile_comments.append(a_href_url)
                                Name.append(a_tag.get_text())    
                
            #Extraction of comments :
                                
            div=soup.find_all('div')
            div_text=[i.get_text() for i in div]
            
            aa,aa1=[],[]
            for i in div_text:
                if i not in aa:
                    aa.append(i)
            for j in aa:
                if 'Like · React · Reply · More ·' in j and 'View more comments…' not in j: 
                    aa1.append(j)
                    
            ll=[' ' for i in range(len(Name))]
            if Name !=[]:
                for i in range(len(Name)):
                    for j in aa1:
                        if Name[i] in j:
                            com=j.split(Name[i])[1]
                            ll[i]=com.split("Like")[0].replace('"','')
                            if 'Edited ·' in ll[i]:
                                ll[i]=com.split("Edited ·")[0]
               
                    for i in range(len(Name)):
                        
                        d_comments[Name[i]]=ll[i]            
                        d_profiles[Name[i]]=profile_comments[i]
            nbr=len(d_comments.keys())
            
            more=self.more_comments(soup)
            if more !=None:
                more='https://mbasic.facebook.com'+ more
                soup=self.get_page(more,session)
                
            else:
                break     
            
        
        d_comments=json.dumps(d_comments, ensure_ascii=False).encode('utf8').decode()
        d_profiles=json.dumps(d_profiles, ensure_ascii=False).encode('utf8').decode()
        return d_comments,d_profiles
        
    
    
        
    def LoginErr(self,page):
        if page.status_code != 200:
            return sys.exit("\n 1-The email or password that you've entered is incorrect OR This keyword cannot find any post :(\n2-Maybe Facebook is asking to conform your identity(cheek you account and change your IP adress).")
       
        else :
            return "--------------------------------\n|         Welcome to           |\n|    Facebook Scraping Tool    |\n--------------------------------"
# Out:
# Logged In

# %%
FP=FacebookPost() # create a new object of FacebookPost class
   
session=rq.Session()
adapter = rq.adapters.HTTPAdapter(max_retries=20)
session.mount('https://', adapter)
session.mount('http://', adapter)

# %%
#OUTPUTS
Urls_list,description,ALL_Reactions,Name,Profile_url,URLS,Images,Date,Scraping_Date=([] for i in range(9))
Like,Angry,Love,Haha,Sad,Care,Wow=([] for i in range(7))#Reactions
Comments,Who_Comment=[],[] #Comments

# %%
#User intput:
file_name="test1"
key="https://www.facebook.com/search/posts/?q=fc%20barcelona"
key_name="https://www.facebook.com/search/people/?q=fc%20barcelona"

# %%
NB_posts=5

comments_limit=1

# %%
Request_URL=FP.url_Keyword(key)
print(Request_URL)
Request_URL_name=FP.url_Keyword(key_name)
print(Request_URL_name)
page=FP.parse_html(Request_URL,session)   
print(page)
page_name=FP.parse_html(Request_URL_name,session)   
print(page_name)
# Out:
# https://mbasic.facebook.com/search/posts/?q=fc%20barcelona
# https://mbasic.facebook.com/search/people/?q=fc%20barcelona
# <Response [404]>
# <Response [404]>

# %%
#Test if the page is successfully loaded :
a=FP.LoginErr(page) 
print(a)
a_name=FP.LoginErr(page_name) 
print(a_name)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit:
#  1-The email or password that you've entered is incorrect OR This keyword cannot find any post :(
# 2-Maybe Facebook is asking to conform your identity(cheek you account and change your IP adress).
# /home/wandra/Documents/Precog/PrecogVenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#Beautiful Soup Object:    
soup=FP.Soup(page)  
print("\nPLEASE WAIT... THIS PROCESS WILL TAKE SOME TIME") 
soup_name=FP.Soup(page_name)  
print("\nPLEASE WAIT... THIS PROCESS WILL TAKE SOME TIME")

# %%
# soup
Urls_list,URLS,ALL_Reactions,Date = FP.posts_info(soup,Urls_list,ALL_Reactions,URLS,Date)
# Urls_list,URLS,ALL_Reactions,Date = FP.posts_info(soup,Urls_list,ALL_Reactions,URLS,Date)

# %%
Urls_list
# Out:
# ['https://mbasic.facebook.com/story.php?story_fbid=256409806644813&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=2032298210271303&id=420669394767534&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143336172618776&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393344916051635&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393439276042199&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393510559368404&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=5161360827231246&id=770861636281209&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393312272721566&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3080012735598602&id=1509269576006267&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=1604222329939949&id=291634874532041&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=4813981505376428&id=1632182286889715&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=5099695703415695&id=197381280313853&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/165078681223039/permalink/543759076688329/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=1604571579905024&id=291634874532041&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364881142306717&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393092322743561&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393126662740127&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143441645941562&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=5284158108285009&id=2044184062282446&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=5162299220470740&id=770861636281209&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=318870566938046&id=102172681941170&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393273756058751&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/165078681223039/permalink/544028586661378/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=5284085764958910&id=2044184062282446&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10159991766324238&id=84434804237&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364836442311187&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364763752318456&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=343013854499218&id=100063718180231&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393411129378347&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=365181755609989&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364865515641613&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364850072309824&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393135852739208&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/726288011590135/permalink/947674109451523/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364831938978304&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/158477655991929/permalink/465734485266243/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393321356053991&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143340265951700&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=130859226108732&id=100075539659725&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=365183308943167&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143086515977075&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/1021983918006231/permalink/1826728900865058/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393427326043394&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393340549385405&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143437635941963&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364881685639996&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143384502613943&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=5095233387179846&id=187991754570725&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3143084825977244&id=1375315529420858&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393420599377400&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10161112031854305&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10161108727549305&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=365186022276229&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393524736033653&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=7337896959554510&id=746781001999505&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364764492318382&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=7338553746155498&id=746781001999505&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10159101037942946&id=81286652945&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=365182562276575&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=480744436740150&id=100044137941494&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364865082308323&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/165078681223039/permalink/543932686670968/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=502237581260054&id=100044214500448&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393534982699295&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393483546037772&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/Internationalchampionscup/photos/a.660756337284864/5731483350212112/?type=3&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3062350217242470&id=1032164243594421&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/barcanewshub/permalink/995541581399135/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/leomessiworldfans/permalink/4954560817958169/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393339719385488&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/groups/barcanewshub/permalink/995468754739751/?__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3071045826443786&id=1635412586673791&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364666162328215&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=7338674639476742&id=746781001999505&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393391642713629&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10161087920239305&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=335181741953779&id=100294555442500&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10161112127379305&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=521563156004317&id=100044519105951&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393008339418626&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364838485644316&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393097412743052&id=100061283902355&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=3217148295229000&id=1478526435757870&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=364814222313409&id=100063545028703&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10161095143174305&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=123433776909149&id=110663811519479&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=339622861509358&id=100063849394283&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=10161095253394305&id=197394889304&__tn__=%2AW#footer_action_list',
#  'https://mbasic.facebook.com/story.php?story_fbid=393462749373185&id=100061283902355&__tn__=%2AW#footer_action_list']
